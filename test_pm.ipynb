# %%
import photomesh

result = photomesh.map_texture(
    dataset_dir="dataset/",
    mesh_name="poisson.ply",
    texture_size=4096,
    uv_method="xatlas",
    view_selector="closest_z",
    inpaint=True,
    color_match=False,            # match illumination across views
    color_match_method="mkl",
    color_match_ref=0,           # use first image as reference
    subdivide=0,                 # set to 2 for subdivision
    output_dir="outputs/",       # auto-save OBJ + PLY
)

mesh = result.get_open3d_mesh()
print(f"Open3D mesh: {len(mesh.vertices)} verts, {len(mesh.triangles)} tris")
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [1/4] Loading mesh ...
#   Mesh: 18759 verts, 37514 tris
# [2/4] Loading COLMAP cameras ...
#   23 cameras loaded
# [3/4] UV-unwrapping ...
#   UV: 25414 verts, 37514 tris
# [4/4] Loading images & projecting ...
#   Loaded 23 images
#   Rasterising UV atlas (4096x4096) ...
#     tri 0/37514 (0%) — 0 texels filled
#     tri 4000/37514 (11%) — 1053017 texels filled
#     tri 8000/37514 (21%) — 2027289 texels filled
#     tri 12000/37514 (32%) — 3022502 texels filled
#     tri 16000/37514 (43%) — 4024858 texels filled
#     tri 20000/37514 (53%) — 5086700 texels filled
#     tri 24000/37514 (64%) — 6157064 texels filled
#     tri 28000/37514 (75%) — 7160720 texels filled
#     tri 32000/37514 (85%) — 8158802 texels filled
#     tri 36000/37514 (96%) — 9213553 texels filled
#   Filled 9601709 texels total
# ...
